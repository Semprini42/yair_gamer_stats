# %%
import requests

def create_access_token(client_id, client_secret, region = 'eu'):
    data = { 'grant_type': 'client_credentials' }
    response = requests.post('https://%s.battle.net/oauth/token' %region, data=data, auth=(client_id, client_secret))
    return response.json()

response = create_access_token('7865953cf15a48ffb6e6b8c2d9fe27e8', 'tVvOpeaDm0C85MBq5s5hugaaeDaOh5rb')
print(response)
# Out:
# {'access_token': 'EUKIJgxYWQmWod1Bzrrz66UZW19aQtHJa7', 'token_type': 'bearer', 'expires_in': 86399, 'sub': '7865953cf15a48ffb6e6b8c2d9fe27e8'}

# %%
client_id = '7865953cf15a48ffb6e6b8c2d9fe27e8'
client_secret = 'tVvOpeaDm0C85MBq5s5hugaaeDaOh5rb'

para = {'namespace': 'profile-eu', 'locale': 'en_GB', 'access_token': 'EUKIJgxYWQmWod1Bzrrz66UZW19aQtHJa7'}
test = requests.get('https://eu.api.blizzard.com/profile/user/wow', params=para, auth=(client_id, client_secret))
test
# Out:
# <Response [401]>

# %%
from win32gui import FindWindow, GetWindowText
import win32gui

foobar = FindWindow('Battle.net', None)
text = GetWindowText(foobar)
text
# Out:
# ''

# %%
from win32gui import GetWindowText, GetForegroundWindow
import win32gui

while True:
    window = GetForegroundWindow()
    print(window.real)
    # print (GetWindowText(window))
# Out:
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# 7014168
# ...
